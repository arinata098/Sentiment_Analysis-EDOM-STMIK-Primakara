# %% [markdown]
# ## Import Library

# %%
# Import some libraries

import pandas as pd
pd.options.mode.chained_assignment = None
import numpy as np
seed = 0
np.random.seed(seed)
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style = 'whitegrid')
import statistics

import re
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict, cross_validate
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, make_scorer
from keras.models import Sequential
from keras.layers import Embedding, Dense, Dropout, LSTM
from keras.optimizers import Adam, RMSprop, SGD
from keras.callbacks import EarlyStopping
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Initialize Data

# %%
data_komentar = pd.read_csv('data/with_neutral_string.csv')
coments = data_komentar
coments
# Out:
#       id_komentar sentimenc2 sentimenc2np sentimenc3  \
# 0            4465   positive     positive    neutral
# 1            3922   positive     positive   positive
# 2             723   negative     negative   negative
# 3            2672   negative     negative   negative
# 4            3883   positive     positive   positive
# ...           ...        ...          ...        ...
# 4571         3364   negative     negative   negative
# 4572         2287   positive     positive   positive
# 4573         2622   negative     negative   negative
# 4574         3315   positive     positive   positive
# 4575          472   positive     positive   positive
#
#                                                komentar
# 0              sepertinya tidak ada yang perlu dikritik
# 1     terimakasih sudah menjadi dosen yang mengerti ...
# 2     untuk penjelasan meteri dan sebagainya mohon l...
# 3                      seringnya perbatalan perkuliahan
# 4     menurut saya cara mengajar yang diterapkan sud...
# ...                                                 ...
# 4571  penjelasan disetiap materi kurang merinci maha...
# 4572               sudah bagus dalam penyampaian materi
# 4573  kualitas ajar yang kurang menyebabkan mahasisw...
# 4574  saya ngga ada kritik sama ibu pokoknya the bes...
# 4575                     cara mengajar yang sangat baik
#
# [4576 rows x 5 columns]

# %% [markdown]
# ## Fungsi untuk Preprocessing text

# %%
# Some functions for preprocessing text

def cleaningText(text):
    text = re.sub(r'@[A-Za-z0-9]+', '', text) # remove mentions
    text = re.sub(r'#[A-Za-z0-9]+', '', text) # remove hashtag
    text = re.sub(r'RT[\s]', '', text) # remove RT
    text = re.sub(r"http\S+", '', text) # remove link
    text = re.sub(r'[0-9]+', '', text) # remove numbers

    text = text.replace('\n', ' ') # replace new line into space
    text = text.translate(str.maketrans('', '', string.punctuation)) # remove all punctuations
    text = text.strip(' ') # remove characters space from both left and right text
    return text

def casefoldingText(text): # Converting all the characters in a text into lower case
    text = text.lower() 
    return text

def tokenizingText(text): # Tokenizing or splitting a string, text into a list of tokens
    text = word_tokenize(text) 
    return text

def filteringText(text): # Remove stopwors in a text
    listStopwords = set(stopwords.words('indonesian'))
    exclude_word = set(('tidak', 'bukan', 'kurang', 'belum', 'menyimpang', 'jangan', 'tak', 'tiada', 'engga', 'enggak', 'ndak', 'kagak'))
    finalStopword = listStopwords.difference(exclude_word)
    filtered = []
    for txt in text:
        if txt not in finalStopword:
            filtered.append(txt)
    text = filtered 
    return text

def stemmingText(text): # Reducing a word to its word stem that affixes to suffixes and prefixes or to the roots of words
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    text = [stemmer.stem(word) for word in text]
    return text

def toSentence(list_words): # Convert list of words into sentence
    sentence = ' '.join(word for word in list_words)
    return sentence

# %%
coments['text_clean'] = coments['komentar'].apply(cleaningText)
coments['text_clean']
# Out:
# 0                sepertinya tidak ada yang perlu dikritik
# 1       terimakasih sudah menjadi dosen yang mengerti ...
# 2       untuk penjelasan meteri dan sebagainya mohon l...
# 3                        seringnya perbatalan perkuliahan
# 4       menurut saya cara mengajar yang diterapkan sud...
#                               ...
# 4571    penjelasan disetiap materi kurang merinci maha...
# 4572                 sudah bagus dalam penyampaian materi
# 4573    kualitas ajar yang kurang menyebabkan mahasisw...
# 4574    saya ngga ada kritik sama ibu pokoknya the bes...
# 4575                       cara mengajar yang sangat baik
# Name: text_clean, Length: 4576, dtype: object

# %%
coments['text_clean'] = coments['komentar'].apply(casefoldingText)
coments['text_clean']
# Out:
# 0                sepertinya tidak ada yang perlu dikritik
# 1       terimakasih sudah menjadi dosen yang mengerti ...
# 2       untuk penjelasan meteri dan sebagainya mohon l...
# 3                        seringnya perbatalan perkuliahan
# 4       menurut saya cara mengajar yang diterapkan sud...
#                               ...
# 4571    penjelasan disetiap materi kurang merinci maha...
# 4572                 sudah bagus dalam penyampaian materi
# 4573    kualitas ajar yang kurang menyebabkan mahasisw...
# 4574    saya ngga ada kritik sama ibu pokoknya the bes...
# 4575                       cara mengajar yang sangat baik
# Name: text_clean, Length: 4576, dtype: object

# %%
coments.drop(['komentar'], axis = 1, inplace = True)

# %%
coments['text_preprocessed'] = coments['text_clean'].apply(tokenizingText)
coments['text_preprocessed']
# Out:
# 0         [sepertinya, tidak, ada, yang, perlu, dikritik]
# 1       [terimakasih, sudah, menjadi, dosen, yang, men...
# 2       [untuk, penjelasan, meteri, dan, sebagainya, m...
# 3                    [seringnya, perbatalan, perkuliahan]
# 4       [menurut, saya, cara, mengajar, yang, diterapk...
#                               ...
# 4571    [penjelasan, disetiap, materi, kurang, merinci...
# 4572           [sudah, bagus, dalam, penyampaian, materi]
# 4573    [kualitas, ajar, yang, kurang, menyebabkan, ma...
# 4574    [saya, ngga, ada, kritik, sama, ibu, pokoknya,...
# 4575                 [cara, mengajar, yang, sangat, baik]
# Name: text_preprocessed, Length: 4576, dtype: object

# %%
coments['text_preprocessed'] = coments['text_preprocessed'].apply(filteringText)
coments['text_preprocessed']
# Out:
# 0                                       [tidak, dikritik]
# 1               [terimakasih, dosen, mengerti, mahasiswa]
# 2         [penjelasan, meteri, mohon, diperjelas, ya, bu]
# 3                               [perbatalan, perkuliahan]
# 4                                  [mengajar, diterapkan]
#                               ...
# 4571    [penjelasan, disetiap, materi, kurang, merinci...
# 4572                         [bagus, penyampaian, materi]
# 4573    [kualitas, ajar, kurang, menyebabkan, mahasisw...
# 4574    [ngga, kritik, pokoknya, the, best, buk, suka,...
# 4575                                           [mengajar]
# Name: text_preprocessed, Length: 4576, dtype: object

# %%
coments['text_preprocessed'] = coments['text_preprocessed'].apply(stemmingText)
coments['text_preprocessed']
# Out:
# 0                                         [tidak, kritik]
# 1                   [terimakasih, dosen, erti, mahasiswa]
# 2                    [jelas, meter, mohon, jelas, ya, bu]
# 3                                         [batal, kuliah]
# 4                                           [ajar, terap]
#                               ...
# 4571    [jelas, tiap, materi, kurang, merinci, mahasis...
# 4572                              [bagus, sampai, materi]
# 4573    [kualitas, ajar, kurang, sebab, mahasiswa, tid...
# 4574    [ngga, kritik, pokok, the, best, buk, suka, ke...
# 4575                                               [ajar]
# Name: text_preprocessed, Length: 4576, dtype: object

# %%
# drop duplicates/spams tweets
coments.drop_duplicates(subset = 'text_clean', inplace = True)

# %%
# Export to csv file
# coments.to_csv(r'data/coments_data_clean.csv', index = False, header = True,index_label=None)

# coments

# %% [markdown]
# ## Analysis and Visualization
#
# ## Comparasion Class Sentiment on Data

# %%
fig, ax = plt.subplots(figsize = (6, 6))
sizes = [count for count in coments['sentimenc2np'].value_counts()]
labels = list(coments['sentimenc2np'].value_counts().index)
explode = (0.01, 0.01)
ax.pie(x = sizes, labels = labels, autopct = '%1.1f%%', explode = explode, textprops={'fontsize': 14})
ax.set_title('Class Sentiment on Data Komentar \n', fontsize = 16, pad = 20)
plt.show()

# %% [markdown]
# # Sentiment Analysis Using LSTM

# %% [markdown]
# ## Preprocessing Text Data

# %%
# Make text preprocessed (tokenized) to untokenized with toSentence Function
X = coments['text_preprocessed'].apply(toSentence)
X
# Out:
# 0                                            tidak kritik
# 1                        terimakasih dosen erti mahasiswa
# 2                           jelas meter mohon jelas ya bu
# 3                                            batal kuliah
# 4                                              ajar terap
#                               ...
# 4571    jelas tiap materi kurang merinci mahasiswa tid...
# 4572                                  bagus sampai materi
# 4573    kualitas ajar kurang sebab mahasiswa tidak ert...
# 4574    ngga kritik pokok the best buk suka kelas ken ...
# 4575                                                 ajar
# Name: text_preprocessed, Length: 4569, dtype: object

# %%
max_features = 5000

# Tokenize text with specific maximum number of words to keep, based on word frequency
tokenizer = Tokenizer(num_words=max_features, split=' ')
tokenizer.fit_on_texts(X.values)

X = tokenizer.texts_to_sequences(X.values)

X
# Out:
# [[3, 13],
#  [22, 9, 12, 4],
#  [16, 1211, 33, 16, 56, 21],
#  [551, 7],
#  [1, 182],
#  [1, 1, 21, 552, 1],
#  [199, 553],
#  [3, 18, 13, 413, 846, 1],
#  [14, 2, 18, 1212],
#  [3, 847, 9],
#  [19, 233],
#  [3, 13, 24, 7, 18, 1, 17, 10, 2],
#  [3, 247, 4, 23],
#  [9, 11, 12, 4, 7],
#  [63, 7, 135],
#  [124, 5, 12, 212],
#  [65],
#  [67, 414, 37, 7, 72, 2, 20, 10],
#  [1, 17, 12],
#  [74, 40, 479],
#  [82, 1],
#  [25, 2, 113, 10],
#  [13, 3, 248, 1, 480, 65, 1, 222, 177, 131, 280, 1, 32, 78, 154, 41],
#  [2, 30, 93, 17, 10],
#  [267, 1213, 35],
#  [114, 3, 19, 14, 2],
#  [848, 1],
#  [554, 45, 555, 342, 8, 99, 21, 183],
#  [680, 481, 19, 343, 1214, 281, 183],
#  [70, 29, 10, 2, 849, 5, 309, 70, 1215, 103, 29],
#  [3, 13, 21],
#  [7, 482, 162, 72, 67, 2, 850, 150],
#  [15, 75],
#  [3, 38, 1216, 3, 851],
#  [2, 282, 5, 200, 29, 141],
#  [1217],
#  [5, 1218, 124, 4, 283, 124, 136, 1219],
#  [310, 75],
#  [5, 4, 2, 18, 16],
#  [5, 16, 2, 4, 3, 4, 6, 1220, 16, 2],
#  [33, 2],
#  [33, 51, 5, 852, 282, 45, 43, 81, 6],
#  [1, 374, 22],
#  [5, 4, 12, 483],
#  [681, 2],
#  [9, 57, 29, 234],
#  [5, 10, 16, 2, 27, 49, 415],
#  [5, 120, 21],
#  [45, 5, 104, 6, 4],
#  [4, 1221, 375, 233, 56, 36, 3, 36],
#  [556, 110, 17, 213, 416, 557, 96, 268, 34],
#  [31, 10, 1222, 155, 8],
#  [14, 2, 11, 39, 311, 4, 1, 558, 682, 2],
#  [22, 284, 78, 42],
#  [2, 5, 125, 1223, 51, 56, 853, 312, 1224],
#  [34, 81, 24, 7, 91, 854],
#  [559, 15, 36, 75],
#  [],
#  [9, 223],
#  [9, 1, 17, 10],
#  [19, 2, 4, 20, 12, 190, 4, 150, 1225, 4, 3, 417, 855],
#  [],
#  [2, 484, 39, 3, 38, 30, 2, 485, 313, 1, 44, 313, 4, 39, 48, 81, 126, 7],
#  [20, 13],
#  [1226, 856, 42],
#  [29, 2, 4, 344, 376, 418],
#  [14, 486, 14, 5],
#  [857],
#  [14, 2, 214, 269, 65, 345, 97, 65, 1, 82],
#  [132],
#  [37, 115, 111, 9],
#  [2, 30, 129],
#  [83, 8],
#  [3, 156, 7, 72, 4, 3, 9],
#  [16, 79, 1227, 1228],
#  [167, 285, 419, 66, 2],
#  [270, 1, 1229],
#  [1230],
#  [5, 224],
#  [32, 50],
#  [377, 42, 1231],
#  [25],
#  [47, 49, 6],
#  [1, 858, 9, 1232, 124, 487, 74, 560, 561, 1233, 859, 314, 378],
#  [4, 247],
#  [9, 3, 249],
#  [346, 1, 42, 315],
#  [15, 151, 142, 488, 42],
#  [7, 70, 7, 562],
#  [683, 52, 99, 21, 15],
#  [22, 78, 53, 2, 17, 12],
#  [58, 1],
#  [5, 41, 26, 6, 1234],
#  [9, 1235, 42, 347, 377, 42, 347, 191],
#  [6, 100],
#  [56, 47, 49, 4, 860],
#  [51,
#   235,
#   3,
#   36,
#   24,
#   7,
#   249,
#   63,
#   24,
#   7,
#   480,
#   24,
#   7,
#   684,
#   489,
#   236,
#   110,
#   344,
#   3,
#   10,
#   685,
#   28,
#   490,
#   1236,
#   6,
#   861],
#  [1, 24, 7],
#  [25],
#  [14, 2, 2, 27, 59, 201, 2, 420, 286, 215],
#  [3, 54, 16, 6, 156],
#  [686, 42, 1237, 1, 18, 163],
#  [3, 287, 1, 20, 12, 4],
#  [3, 1],
#  [5, 66, 137, 124, 4],
#  [70, 31, 4],
#  [687, 55, 1238, 154, 9, 56, 862, 6, 107, 9, 202, 863, 154],
#  [1, 5],
#  [237],
#  [16, 2, 27, 20],
#  [9, 112, 4, 143, 30, 3, 9, 4, 316, 9, 563, 9, 421, 4, 3, 864, 864, 1239],
#  [1, 59, 5, 564],
#  [1240, 203, 42],
#  [1],
#  [5, 316, 865],
#  [16, 2, 17, 10],
#  [866, 13, 1],
#  [3, 35, 72, 7, 70],
#  [3, 316, 184, 4],
#  [1],
#  [25, 1241],
#  [16, 19],
#  [29, 185, 9, 57],
#  [1, 2],
#  [23, 4],
#  [317, 1242, 157, 164, 1],
#  [565],
#  [3, 40, 7],
#  [15, 64, 56, 91],
#  [2, 29, 12, 1243, 1244],
#  [165, 9, 4],
#  [14, 2, 18, 5],
#  [28, 15, 142],
#  [5, 120, 867],
#  [14, 54, 39, 3, 38, 2],
#  [566, 422, 567, 8, 4, 5],
#  [3, 318, 84, 52],
#  [44, 5, 238, 204, 3, 1245, 9, 36, 1246, 4, 1, 271, 110],
#  [8, 8, 103, 31, 250],
#  [57, 4, 568, 93],
#  [1, 11, 3, 13, 868],
#  [3, 13, 1, 9],
#  [3, 18, 13, 25],
#  [],
#  [1, 9, 2],
#  [21,
#   319,
#   150,
#   11,
#   68,
#   91,
#   75,
#   75,
#   223,
#   4,
#   98,
#   4,
#   99,
#   869,
#   9,
#   48,
#   99,
#   24,
#   7,
#   870,
#   216,
#   4,
#   871],
#  [72],
#  [8, 55, 251, 872, 152],
#  [1, 46, 379, 5, 11, 688, 1, 36, 12, 22],
#  [9, 105],
#  [1, 121, 3, 348, 320, 6, 281, 87, 58, 81, 6],
#  [76, 23, 5, 12],
#  [37, 873],
#  [3, 18, 689, 690],
#  [29, 691],
#  [2, 1, 97],
#  [35, 3, 12, 2, 69, 186],
#  [1247],
#  [8, 491, 1248],
#  [5, 214, 269, 14, 2],
#  [5, 223],
#  [1, 3, 61, 55, 4, 39, 29, 10],
#  [13, 205, 2, 204, 569, 22],
#  [158, 1, 11, 14, 2, 141, 4, 12, 164, 1, 874, 43, 94, 199, 126, 875, 7, 380],
#  [36, 202, 163, 492, 876, 6, 551, 321],
#  [91, 1249],
#  [28, 217, 6, 16, 2],
#  [3, 1250, 73],
#  [349, 1251, 101],
#  [5, 8],
#  [5, 41, 26, 6],
#  [13, 1, 46, 288, 159, 570, 252, 3, 191, 168, 252, 3, 142, 183],
#  [225, 14, 2, 26, 6, 41],
#  [22,
#   319,
#   1,
#   77,
#   77,
#   381,
#   144,
#   350,
#   24,
#   7,
#   692,
#   693,
#   160,
#   21,
#   13,
#   56,
#   124,
#   157,
#   7,
#   177,
#   13,
#   1252,
#   1253],
#  [28, 571, 1, 6, 92],
#  [493, 15, 1254],
#  [8, 1255, 23, 1256],
#  [2, 29, 10],
#  [1, 17, 12],
#  [1, 11],
#  [32, 50, 121, 1],
#  [2, 19],
#  [21],
#  [51, 1, 15, 192, 6, 5, 121],
#  [1, 26, 6, 3, 64],
#  [22, 1, 21],
#  [1257, 351, 1],
#  [877, 7, 3, 572, 62, 1, 1, 38, 878],
#  [47, 2, 6],
#  [41, 573, 6, 1258],
#  [3],
#  [5],
#  [9, 17, 253],
#  [9, 574],
#  [2, 17, 12, 6, 34],
#  [27, 29, 1259, 9],
#  [7, 3, 322, 879],
#  [1, 310],
#  [2, 17, 10, 694, 2, 164, 1, 272, 47, 6, 72, 162, 37, 156, 154, 61, 65, 1, 97],
#  [1, 34, 41, 26, 6],
#  [8, 8, 695, 52, 193, 106],
#  [28, 4, 55, 133, 575, 1260, 77, 77, 3, 153, 133, 55],
#  [],
#  [28, 382, 4, 56, 15, 144, 576, 122, 23],
#  [5, 142, 696, 46, 1261, 289, 19, 1262],
#  [559, 113, 1],
#  [3, 1, 11],
#  [3, 13, 14, 2, 7, 2, 8, 577, 2, 383, 103, 10, 1],
#  [39, 2, 31, 12, 19, 2],
#  [15, 1263, 8, 3, 254, 77, 18, 1264],
#  [1265, 255, 138, 145],
#  [25],
#  [5, 10, 2],
#  [9, 880, 13, 20],
#  [86, 1, 376, 80],
#  [193, 106, 578, 1266, 40, 490, 881, 68],
#  [3, 13, 11, 187],
#  [25, 1],
#  [61, 218, 133, 5, 11],
#  [3, 13, 1],
#  [2, 116, 31, 10],
#  [9, 92],
#  [14, 2, 11, 1, 11, 10, 1, 94],
#  [15, 203, 203, 56, 42],
#  [9],
#  [11, 206, 1, 6, 4, 17, 12, 1, 1267],
#  [15, 3, 60, 6, 80, 20, 12, 19],
#  [579, 697, 4],
#  [11, 1, 23, 36],
#  [33, 51, 290, 323, 13, 157, 1, 66, 45, 43],
#  [565, 56, 42, 1268, 81, 106, 75, 40],
#  [239, 1, 698],
#  [3, 13, 3, 13],
#  [13, 60, 23, 5, 37, 60],
#  [76, 6, 21],
#  [1],
#  [8, 1269, 56, 139, 57, 155, 46],
#  [226, 2],
#  [54, 4, 321],
#  [61, 256, 57, 93, 23],
#  [2, 27, 27, 3],
#  [3, 13],
#  [51, 580, 1270, 1271, 1, 25],
#  [1272, 30, 18, 157, 423, 41, 882, 18],
#  [1273, 10, 273],
#  [3, 1274, 36, 1],
#  [5, 127, 4, 4, 5, 87, 424, 1275, 2],
#  [84, 4, 1276, 883, 252, 699, 20, 274, 494, 3, 9, 4, 1, 495],
#  [101, 1, 12],
#  [5, 92],
#  [68, 53, 2, 11, 35, 1277, 324],
#  [153, 4, 3, 12, 15, 1278, 4, 3, 1, 45, 24, 7],
#  [1279, 3, 1],
#  [9, 185, 12, 4],
#  [49, 6, 54, 4],
#  [1, 115, 111, 68, 46],
#  [41, 26, 7, 99],
#  [115, 111, 4],
#  [138, 145, 700, 137, 137, 13, 1280],
#  [496, 1],
#  [1, 1, 4, 884, 12, 4, 20, 10, 57, 885, 2],
#  [1281, 1, 11, 4, 1, 129, 38, 886],
#  [11, 42, 146],
#  [2],
#  [576, 166],
#  [92, 52, 193, 20, 66],
#  [132, 1282, 4, 18, 5, 19, 12],
#  [5, 41, 26, 6, 6, 497, 6, 144],
#  [2, 291, 44, 887, 224, 425, 1283, 1284, 44, 887, 4, 3, 69, 12, 2],
#  [1, 1285, 43, 3, 13],
#  [34, 1, 33, 51, 37, 10, 2, 108, 6, 177, 162, 37, 10, 2],
#  [9, 194, 11, 69, 1, 71, 3, 73, 61, 1, 23, 11, 14, 2, 29, 10],
#  [58],
#  [1],
#  [33, 51, 20],
#  [5, 178, 275, 80],
#  [33, 16, 1286, 24, 7, 581, 8, 1287, 215, 251],
#  [2, 5, 12, 4, 5, 30, 2, 5, 582, 4, 26, 6, 3, 41, 59],
#  [24, 7, 34, 50, 1],
#  [86, 375, 375],
#  [3],
#  [2, 384, 583, 23, 21, 183],
#  [48, 257, 8, 147, 4, 195, 1288, 5, 1289],
#  [19, 19, 426],
#  [2, 6, 59],
#  [28, 1290, 193, 15, 322, 1291, 52, 481, 48, 1292, 20, 129, 8],
#  [3, 52, 94, 37, 7],
#  [15, 8, 236],
#  [11, 5, 35, 4, 5, 10, 1293, 1],
#  [13, 16, 5, 30],
#  [2, 1294, 71],
#  [5, 888, 1, 70],
#  [120, 5, 200, 160],
#  [33, 30, 93, 292, 240],
#  [14, 53, 8],
#  [1, 889, 69, 30, 20, 10, 102, 20, 890, 44, 85],
#  [13, 37, 1],
#  [2, 5, 17, 10],
#  [3],
#  [1, 44, 293, 82, 8, 1295, 1296],
#  [2, 1, 11, 352, 14, 4, 5, 25],
#  [179, 2, 258, 241],
#  [891, 142, 7],
#  [7, 701, 68, 561, 5, 12, 2, 1, 5, 10, 4, 325, 107, 1297],
#  [148, 207],
#  [5, 184, 4, 47, 498, 353, 3, 9, 47, 584, 353, 499, 316, 3],
#  [585, 1298, 28],
#  [1,
#   20,
#   59,
#   102,
#   1299,
#   242,
#   284,
#   284,
#   36,
#   20,
#   59,
#   204,
#   249,
#   1300,
#   4,
#   1,
#   56,
#   32,
#   3,
#   1301,
#   59,
#   204,
#   1302],
#  [178],
#  [259, 2, 158, 4, 123, 30, 17, 12],
#  [2, 200],
#  [15, 892, 113, 4, 3, 241],
#  [3, 13, 34, 1],
#  [893],
#  [9, 1303, 1304],
#  [116, 2, 200],
#  [343, 14, 27, 290, 323],
#  [3, 60],
#  [2, 20, 1],
#  [250, 7, 70, 318, 4, 31, 169, 294],
#  [5, 147, 8],
#  [500, 1305, 99],
#  [22, 57, 97, 43],
#  [14, 11],
#  [28, 49, 6, 326, 327, 40, 24, 894, 352, 78, 66, 1306, 47, 22],
#  [14, 2, 170],
#  [1307, 1308, 45, 43, 1],
#  [1, 3, 38],
#  [493, 28, 2, 23, 16, 427, 1309, 702, 1310],
#  [428, 102, 3, 295, 55],
#  [3, 7, 72, 35, 227, 8, 162],
#  [5, 79, 16, 2, 39, 1, 59],
#  [13, 3, 1311],
#  [1],
#  [14, 2, 17, 61, 115, 111, 69, 260, 250, 3, 484, 68, 46, 109, 14, 2, 17, 10],
#  [33, 79, 1],
#  [3, 57, 4],
#  [65, 18, 345, 15, 895, 19, 59],
#  [9, 117, 4],
#  [120, 896],
#  [150, 11],
#  [328, 897, 57, 4, 897],
#  [11, 1, 1, 225, 501, 586, 192, 127],
#  [73, 429, 1312],
#  [1, 225, 82],
#  [11],
#  [13, 194, 3, 128, 1, 73, 188],
#  [8, 106, 587, 1313],
#  [100],
#  [35, 67, 2, 18, 38, 4, 3, 48, 129, 292, 81, 1314, 6],
#  [5, 134, 16, 1315, 24, 7],
#  [5, 261, 2, 4, 48],
#  [27, 1316, 26, 64],
#  [15, 36, 75, 49, 6],
#  [11, 55, 4, 274, 3, 502, 2, 37, 1, 2, 5, 346, 4],
#  [58, 1, 4],
#  [247, 41, 26, 6, 107, 14, 2],
#  [235, 690, 8, 503, 1317, 1318, 1],
#  [101, 588],
#  [27, 703, 704, 55, 208, 128],
#  [62, 1, 23],
#  [17, 12, 17, 10, 2],
#  [5, 1],
#  [1319, 9, 589, 1, 184, 14, 2, 79],
#  [5, 261, 2, 7, 4, 3, 590],
#  [1320,
#   226,
#   417,
#   291,
#   385,
#   898,
#   705,
#   591,
#   705,
#   69,
#   1321,
#   899,
#   180,
#   93,
#   234,
#   1322,
#   47,
#   3,
#   184,
#   4,
#   18,
#   1323],
#  [1, 1324, 2, 23, 100, 34],
#  [1325, 42],
#  [1326, 62, 1, 34],
#  [60, 177, 1, 72],
#  [28, 96, 56, 58, 702],
#  [900, 296, 592, 4, 9, 57, 123, 10, 706, 57, 123, 296],
#  [41, 26, 6, 34],
#  [3, 12, 2, 18, 161, 6, 26, 6, 64],
#  [2],
#  [209, 707, 901],
#  [1, 1, 23],
#  [2],
#  [28, 50, 297, 31, 10],
#  [8, 31],
#  [902],
#  [16, 1327, 2, 7, 46],
#  [237, 101],
#  [48, 1328, 903, 171, 430, 20, 1329],
#  [25, 1],
#  [593, 904],
#  [2, 7, 18, 33, 16],
#  [51, 151, 92, 106],
#  [708, 1, 72],
#  [22,
#   1330,
#   1,
#   77,
#   77,
#   381,
#   144,
#   350,
#   24,
#   7,
#   298,
#   1331,
#   1332,
#   13,
#   13,
#   124,
#   157,
#   7,
#   1333,
#   177,
#   13,
#   104,
#   7,
#   594],
#  [11, 25, 1, 109],
#  [33, 35],
#  [153, 4, 6],
#  [196, 427],
#  [3, 125, 13, 2, 11],
#  [9, 57, 4],
#  [51, 13, 140, 1334, 329, 1],
#  [31, 35, 9],
#  [25],
#  [],
#  [9, 57, 4],
#  [1335, 95, 99, 21, 113, 12],
#  [2, 5, 291],
#  [905],
#  [5],
#  [595, 20, 1336, 36, 1, 595],
#  [91, 19],
#  [431],
#  [596, 906, 596, 134, 71, 12],
#  [709, 132, 12],
#  [3, 1],
#  [1337, 710, 14, 2, 354, 7],
#  [15, 8, 80, 144],
#  [16, 2, 18, 66],
#  [597, 135, 40, 7, 321],
#  [22, 21, 1],
#  [154, 44, 85, 16, 2, 20, 12],
#  [1, 69, 19, 2, 6, 46, 3, 35, 69, 318, 2, 20, 432, 29, 10],
#  [2, 1, 11, 154, 330, 41],
#  [386, 54],
#  [5, 10, 148, 907, 598],
#  [14, 2, 711],
#  [3, 9, 1, 4, 23],
#  [50, 6, 562, 708],
#  [35, 61, 1338, 2, 38],
#  [2, 5, 10],
#  [908, 355, 13, 128, 21, 504, 101],
#  [13, 61, 1, 34],
#  [14, 2, 29, 12],
#  [22, 57, 43],
#  [28, 1],
#  [5, 180, 52, 4, 125, 356, 180, 52, 107, 13, 137, 4, 3, 13, 137, 3, 52, 107],
#  [101],
#  [2, 331, 48],
#  [166],
#  [39, 599],
#  [13, 3, 128, 62, 426, 1339, 188],
#  [1340, 141, 18, 1341],
#  [7, 8, 234, 4, 9],
#  [22, 78, 42],
#  [172, 1, 10],
#  [97, 4, 39, 3, 141, 212, 2],
#  [15, 600, 433, 4, 18, 5, 19, 141, 1],
#  [15, 1342, 163, 122, 3, 1, 75],
#  [10, 1],
#  [22, 1],
#  [13, 1343, 27, 27, 712, 909, 1344, 212],
#  [2, 11],
#  [9, 8, 1345, 357, 72, 103, 4, 5, 10, 24, 7],
#  [30, 6],
#  [9, 97],
#  [5, 713, 413],
#  [299, 5],
#  [3, 165],
#  [5, 2],
#  [5, 2],
#  [1346],
#  [14, 2, 11],
#  [228, 77, 47, 601],
#  [53, 2, 17, 10, 69, 30, 2, 1, 67, 61, 11, 21, 12],
#  [36, 1, 146],
#  [16, 44, 17, 12, 1, 6],
#  [122, 93, 169, 5, 332, 910, 1347],
#  [206, 1, 6, 11, 165, 4, 5, 39, 4, 3, 141, 2],
#  [2, 200],
#  [9, 1, 4, 23],
#  [11, 1, 434, 602, 47],
#  [1,
#   5,
#   130,
#   4,
#   714,
#   583,
#   2,
#   37,
#   226,
#   2,
#   115,
#   111,
#   603,
#   4,
#   344,
#   568,
#   298,
#   5,
#   12,
#   44,
#   298,
#   715],
#  [5, 2, 31, 10],
#  [1348, 19],
#  [2, 1349, 16, 72, 4, 48, 10, 2],
#  [3, 911, 13],
#  [3, 356, 4, 124],
#  [15, 358, 40, 1, 229, 1350, 9],
#  [604, 6, 40, 1],
#  [86, 6, 15, 233, 243],
#  [3, 13, 22, 97],
#  [3, 25],
#  [19, 2],
#  [22, 57],
#  [1, 31, 10],
#  [1, 196, 26, 34, 93, 8, 83, 40, 1351, 716, 12, 224, 4, 10, 23],
#  [26, 6, 5, 58],
#  [11],
#  [58],
#  [32, 50, 1, 82, 56, 42],
#  [3, 13, 238, 24, 7],
#  [5, 153, 4, 5, 87, 6],
#  [24, 7, 387, 300, 135, 605, 606, 717, 159, 359, 5, 3, 912, 159, 3, 913, 22],
#  [37, 60, 6],
#  [189],
#  [3, 13, 21, 435, 1352, 9, 505],
#  [914],
#  [53, 8, 48, 915],
#  [857, 506],
#  [229, 40, 1, 8],
#  [3, 13, 388, 149, 68, 7],
#  [8, 3, 38, 24, 7, 103, 11, 1, 1],
#  [58, 1],
#  [1353, 7, 5],
#  [16, 14, 44, 20, 4, 12, 607, 85],
#  [52, 8],
#  [8, 507],
#  [49, 6, 54, 4],
#  [37, 196, 94, 86, 76, 608, 113, 1354],
#  [1355, 2, 20],
#  [98, 13, 149, 99, 1, 374, 609],
#  [219, 31, 66, 1, 46],
#  [14, 2, 170],
#  [1, 36, 1356, 41, 389],
#  [17, 12, 2, 66, 124, 4, 105],
#  [11, 1],
#  [215, 390, 718, 718, 1357, 29, 230],
#  [36],
#  [5, 436, 259, 2],
#  [3, 13, 9, 1],
#  [5, 10, 2, 1, 46, 1358, 21],
#  [27, 27, 75, 49, 6],
#  [3, 194, 22],
#  [8, 216, 41, 29, 262, 97, 110, 18, 155, 99, 1359, 29],
#  [228, 4, 105, 132],
#  [15, 49, 6, 42],
#  [104, 63, 7, 3, 6, 107],
#  [5, 436, 71],
#  [5, 2, 8],
#  [480, 103, 29, 42],
#  [3, 13],
#  [192, 5, 196, 108],
#  [14, 2, 419, 330, 719, 8, 8, 311, 4],
#  [1, 326, 327],
#  [35, 60],
#  [25, 1],
#  [9, 118, 118, 2, 5, 153, 4, 20, 10],
#  [],
#  [228, 5, 8],
#  [58],
#  [5,
#   10,
#   1,
#   18,
#   1,
#   26,
#   64,
#   250,
#   720,
#   508,
#   301,
#   1360,
#   1361,
#   509,
#   18,
#   1,
#   3,
#   1362],
#  [510, 1, 88, 34],
#  [28, 168, 916, 503, 15, 1363, 178, 503],
#  [11, 169, 210, 65, 511, 1364],
#  [1, 47],
#  [1, 512, 1, 5, 109, 24, 7, 169],
#  [3, 13],
#  [1, 17, 10, 6, 100],
#  [3, 14, 2, 95, 101],
#  [67, 2, 168, 331, 207, 2, 24, 7, 424, 917, 11, 263, 1365, 563, 2, 24, 7],
#  [1, 11, 5, 6],
#  [1366,
#   8,
#   8,
#   17,
#   427,
#   493,
#   102,
#   360,
#   20,
#   173,
#   493,
#   1367,
#   437,
#   1368,
#   918,
#   1369,
#   390,
#   3,
#   1370,
#   1371,
#   50,
#   36,
#   333],
#  [5, 6, 72],
#  [146, 21],
#  [37, 610],
#  [13, 15, 919, 1372, 24, 7, 513],
#  [114],
#  [211],
#  [2, 1, 12, 4],
#  [28, 53, 2, 721, 514, 131, 334, 140, 21],
#  [5, 58, 9],
#  [9, 1373, 12, 260, 250, 4, 7, 1374, 9],
#  [2, 16, 9, 7, 70, 29, 10, 2, 254, 692],
#  [1375, 11],
#  [9, 2, 3, 35, 115, 111, 515, 1376, 69, 4, 39, 29, 10, 126, 1377, 59],
#  [1, 70, 611, 360, 8],
#  [1, 388, 1378, 1379, 3, 174, 13],
#  [3, 516, 4, 438, 557],
#  [582, 6],
#  [386, 54],
#  [2, 5, 10, 10, 264, 2],
#  [68, 281, 182, 11, 112, 80, 87, 68, 281, 182, 5, 722, 125, 10, 1380, 4, 1381],
#  [33, 56, 1382, 2, 55, 15, 135],
#  [2, 11, 1, 612],
#  [920],
#  [6, 46, 5, 10, 2],
#  [52, 1383],
#  [175, 8, 33, 15, 89],
#  [25, 1],
#  [2, 31, 12],
#  [3, 13, 439, 439, 440, 254, 18, 186, 4],
#  [15, 55, 21],
#  [27, 2, 29, 12, 856, 921],
#  [58, 90],
#  [220, 1384, 1385, 1386, 16, 140, 3, 238, 4, 441],
#  [61, 1, 517],
#  [1, 244, 59, 922, 2, 1],
#  [5, 10, 2, 27, 27, 10, 27, 27, 20],
#  [2, 1, 30, 30],
#  [1387, 18, 287],
#  [1, 17, 10, 179, 2, 3, 59, 613, 1388, 157, 2, 67],
#  [358, 1389, 56],
#  [43, 168, 35, 323, 312, 98, 1, 1390],
#  [119, 273, 268, 4],
#  [96],
#  [923, 302, 63, 5],
#  [1, 34],
#  [30, 107],
#  [1, 79],
#  [11, 9, 105],
#  [723],
#  [165, 9, 1, 272],
#  [1],
#  [2, 11, 16, 79, 4, 12],
#  [166, 386, 356, 20, 1391, 356, 166],
#  [15, 19, 1, 2, 6, 3, 4, 125, 158],
#  [441, 84, 301],
#  [5, 62, 1, 2],
#  [26, 6, 1392, 87, 87, 5, 5],
#  [1],
#  [3, 22],
#  [155, 572, 1, 509, 38, 724],
#  [211, 310, 16],
#  [1, 14, 11, 6],
#  [28, 1],
#  [2, 39, 29, 10],
#  [9, 1, 3, 13, 18],
#  [31, 10],
#  [3, 554],
#  [14, 2, 264, 4, 17, 12],
#  [1393, 3, 13],
#  [179, 2, 11],
#  [9, 87, 1, 612, 509, 129, 612, 281, 107, 84, 725, 9, 4, 208, 6, 87],
#  [179, 2],
#  [14, 2, 118, 118, 318, 5, 10, 2],
#  [3, 13],
#  [614, 1394],
#  [1],
#  [32, 1395, 245],
#  [726, 1, 88, 192],
#  [20, 13, 595, 9, 92],
#  [2, 9, 79],
#  [147, 197, 1396, 106],
#  [1, 16, 1397, 11],
#  [1, 303, 62, 33, 361],
#  [1, 615, 34, 14, 2],
#  [1, 2, 69, 152, 152, 71, 69, 19],
#  [3, 128, 13, 121, 442, 1398, 349],
#  [31, 358, 9],
#  [36, 9],
#  [5, 12],
#  [1, 8, 106, 27],
#  [2],
#  [5, 58, 1],
#  [8, 101],
#  [112, 4, 84, 5],
#  [245, 924, 616, 443, 925, 251, 443, 251, 716, 513, 1399, 143, 1400, 30],
#  [11],
#  [434, 1401, 80, 12, 2, 423],
#  [1, 5, 16, 2],
#  [2, 23, 19, 3, 4, 19, 12, 44, 298],
#  [1402, 9, 617, 1, 440, 31, 926, 8, 41, 26, 6],
#  [14, 2, 5, 727, 1403, 31, 10],
#  [33, 166],
#  [83, 5, 54, 8, 18, 89],
#  [1, 14, 2, 57, 4, 20, 10, 11],
#  [9, 105, 117],
#  [4, 64, 252],
#  [22, 1404, 484, 417],
#  [9, 105, 24, 7, 17, 12],
#  [37, 60],
#  [55],
#  [22, 42, 276, 1405, 177, 162, 35, 72, 67, 1406],
#  [3, 13],
#  [201, 30, 5, 30, 129],
#  [5, 2, 5, 178],
#  [11, 1],
#  [60, 12, 24, 7, 1],
#  [4],
#  [32, 50, 1, 82],
#  [83, 30, 16, 8, 246, 8, 123],
#  [2, 17, 12, 17, 10, 105, 927],
#  [32, 62, 1, 34],
#  [1, 11, 518, 30, 4],
#  [15, 36, 1407, 63],
#  [1],
#  [9, 11, 1, 9, 208, 126, 1, 582, 7, 1408],
#  [5, 41, 26, 6],
#  [5, 62, 1, 68, 889, 19],
#  [1409],
#  [9, 928, 1410, 68, 54, 105],
#  [98, 13, 108, 510],
#  [1411, 55, 52, 8, 123, 4, 728, 5, 728],
#  [7, 1412],
#  [1413, 891, 142, 321, 7],
#  [11, 1, 95, 95, 38, 929, 4],
#  [66],
#  [30, 4, 16, 1414, 1415],
#  [3, 311, 4, 8, 729, 74, 148, 44, 293, 618, 8],
#  [2, 2, 44, 293],
#  [5, 178, 444],
#  [122, 362, 45, 6, 335],
#  [1, 4, 271, 10, 2],
#  [122, 135, 107, 923, 89],
#  [9, 3, 35, 72],
#  [],
#  [3, 1, 8, 4],
#  [22,
#   619,
#   1,
#   77,
#   77,
#   381,
#   144,
#   350,
#   24,
#   7,
#   701,
#   620,
#   68,
#   54,
#   13,
#   56,
#   124,
#   157,
#   7,
#   9,
#   621,
#   622],
#  [25, 206, 930, 2, 1],
#  [2],
#  [130, 60, 6, 5],
#  [5, 253, 4],
#  [13, 2, 79, 205, 17, 10, 22],
#  [16, 5, 17, 12],
#  [61, 1, 4, 17, 12, 3, 59, 1, 6],
#  [5, 239],
#  [1],
#  [1416, 623, 33, 51, 3, 73],
#  [1, 10, 4],
#  [1417],
#  [79],
#  [39, 5, 10, 2, 23],
#  [7, 82],
#  [1, 73, 11, 27, 204, 16, 257, 379, 27, 9, 257, 379],
#  [32, 50, 62, 1, 34],
#  [1, 68, 265],
#  [5, 30],
#  [16, 27, 29, 12],
#  [5, 11],
#  [14, 2, 39, 90, 1418, 5, 14, 2],
#  [1, 102, 71, 134, 27, 29, 12],
#  [22, 1, 57],
#  [579, 1419, 390, 1420, 481, 21, 1421, 1422, 1423],
#  [95, 95, 2],
#  [3, 127, 1, 199, 931, 1424, 127, 931],
#  [5, 12, 2],
#  [25, 14, 2],
#  [3, 13],
#  [1, 11],
#  [8],
#  [5, 12, 2],
#  [445],
#  [62, 1, 14, 2, 95],
#  [551, 6, 89],
#  [1425],
#  [14, 2, 39, 5, 31, 10],
#  [1426, 1427],
#  [20, 13],
#  [28, 140, 730, 2],
#  [16, 6, 46],
#  [16],
#  [97],
#  [932, 933, 90],
#  [58, 324, 4, 10, 1],
#  [363, 8, 299],
#  [61, 1],
#  [1, 11],
#  [14, 2, 1, 6],
#  [1, 3, 301, 132, 2, 7],
#  [96],
#  [14, 2],
#  [22, 57, 5, 33, 57, 73],
#  [731, 2, 39, 4, 5, 10, 160, 160, 71, 348],
#  [1428, 7, 46, 28, 1, 515, 131, 15, 2, 272],
#  [60, 1429],
#  [142, 1],
#  [28, 229, 499, 75, 732, 446, 42, 336, 688, 443, 1430, 733, 601, 732],
#  [25, 206, 14, 2],
#  [1, 73],
#  [9, 1431, 304, 734, 6, 70, 136, 224, 1432, 142, 1433, 502],
#  [3, 580, 9, 1434, 2, 116, 80, 5],
#  [1, 11, 96, 735, 99, 98, 49, 6],
#  [88, 447, 4],
#  [1, 5, 214, 269],
#  [25, 934, 1],
#  [1, 11, 935],
#  [65, 1, 5, 67, 2],
#  [5, 71],
#  [1, 1435, 3, 736, 2, 18, 19, 74, 4, 3, 12],
#  [25, 43, 43, 11, 1],
#  [28, 196, 1],
#  [42, 86, 624, 364, 1436, 737, 364, 293, 99, 936, 86, 737, 364, 85, 519, 173],
#  [1,
#   121,
#   25,
#   58,
#   4,
#   1,
#   179,
#   2,
#   201,
#   181,
#   27,
#   59,
#   1437,
#   14,
#   2,
#   18,
#   121,
#   208,
#   1438],
#  [1, 11, 96],
#  [1, 5],
#  [25, 206, 1],
#  [45, 43, 20, 738, 131, 70, 165, 4, 9, 20, 295],
#  [37, 76, 6],
#  [1, 11, 96],
#  [29, 210, 292],
#  [73, 188],
#  [209, 9],
#  [9, 105],
#  [13, 332, 126, 171, 22],
#  [2, 16, 17, 4],
#  [55, 8, 8],
#  [8, 30, 17, 4],
#  [20, 13],
#  [3, 13, 11, 1],
#  [95, 95, 91, 739, 4, 12, 56, 21],
#  [2, 740, 30, 12, 4],
#  [14, 2, 17, 12, 34, 239, 1, 5],
#  [34, 1, 12, 6, 741, 937, 329, 938, 3, 939, 391],
#  [1, 100, 58, 112, 49, 6],
#  [2, 1, 9, 10, 722, 4],
#  [1, 34, 3, 10, 102, 118, 118, 433, 2],
#  [504, 940],
#  [30, 65, 30, 17, 10, 4],
#  [1, 32],
#  [377, 42, 347],
#  [20, 569, 2],
#  [9, 3, 59],
#  [5, 4, 392],
#  [1, 11, 10, 158, 80],
#  [33, 51, 21, 235, 4, 428, 1, 3, 2, 67, 8, 2, 235, 4],
#  [32, 1, 225, 501],
#  [14, 2, 258, 103, 173],
#  [75, 54, 6, 3],
#  [1, 378, 50, 79],
#  [10, 2, 116],
#  [58],
#  [191, 28, 15, 1439, 1, 24, 7, 941],
#  [5, 79, 2],
#  [2, 448, 607, 85, 5, 10],
#  [2, 17, 12, 69, 30, 77, 77, 742, 942, 110, 283, 84, 742],
#  [8],
#  [3, 13],
#  [3, 131, 365, 119, 14, 2],
#  [20, 13, 34, 1],
#  [5, 4, 743, 744, 100, 1440, 9, 226, 3, 441],
#  [31, 234, 4, 943],
#  [3, 13, 1, 10],
#  [1, 11, 445],
#  [22, 1, 43],
#  [61, 1, 944, 4, 59, 6],
#  [27, 14, 3, 6, 47, 1441, 4, 6, 47, 492, 3, 60],
#  [745, 69],
#  [11, 1, 1442, 14, 2],
#  [275, 305, 305, 329, 449, 147, 8, 570, 945, 4, 3, 305, 946, 305, 47, 9],
#  [13, 593, 24, 7, 1443, 3, 128, 36, 1, 593, 6, 161, 2, 17, 12, 77, 1444],
#  [54, 93, 169, 23, 1445],
#  [25, 1, 4, 10, 2],
#  [610, 56],
#  [51, 130, 342, 137, 357, 384, 154, 947, 885, 357],
#  [15, 8, 42, 15, 31],
#  [713, 382, 1446, 450, 429, 27, 1447, 27, 1448, 5, 10, 180, 174],
#  [1, 14, 8, 27, 5, 44, 5, 10, 102, 1],
#  [32, 1449, 93, 246],
#  [2,
#   128,
#   1450,
#   9,
#   130,
#   1451,
#   1452,
#   312,
#   1453,
#   1454,
#   1455,
#   1456,
#   948,
#   1457,
#   24,
#   7,
#   11,
#   34,
#   1458],
#  [1, 30, 337, 2],
#  [1, 6, 5, 58, 625, 59],
#  [28, 1459, 7, 40, 520, 7, 15, 1460],
#  [3, 18, 689],
#  [1, 103, 39, 4, 5, 10, 4, 5, 10, 44, 85],
#  [22, 1461, 1],
#  [3, 13, 1462, 4, 23, 1, 3, 1463, 6, 30, 41, 389, 17, 10],
#  [33, 51, 290, 323, 13, 66, 1, 45, 1464],
#  [67, 2, 5, 30, 5, 22],
#  [10, 4],
#  [521, 4],
#  [5, 8],
#  [7, 8, 949, 55, 133, 107, 522, 4],
#  [16, 2, 1465],
#  [9, 5, 261, 2],
#  [28, 207],
#  [510],
#  [1, 1466],
#  [1467, 255, 1468, 1469, 746, 1470, 255, 747, 1471],
#  [100, 3, 59, 26, 1, 149, 393, 394, 64, 102, 20, 10, 2, 1472],
#  [14, 2, 6, 5],
#  [1, 430, 36, 10],
#  [7, 38, 40, 1],
#  [14, 30, 337, 134, 67, 323, 94, 626, 1473, 377, 950, 98, 173],
#  [1, 5, 14, 5, 17, 1474, 4],
#  [5, 951],
#  [5, 12, 1, 23],
#  [195, 27, 3, 38, 2, 166],
#  [3, 174, 13, 11],
#  [1, 59, 31, 10, 5, 10, 2, 230, 2],
#  [1475, 1476, 1477, 138, 952, 748, 138, 1478, 748, 952],
#  [157, 164, 18, 176, 3, 5],
#  [25, 627, 1],
#  [25, 71, 210, 294, 240],
#  [1, 953, 4, 1479, 521],
#  [220, 1, 18, 448, 5, 1480],
#  [270, 1, 11],
#  [14, 2, 954],
#  [4],
#  [15, 90],
#  [749, 2],
#  [68, 1481, 15, 181],
#  [205, 2],
#  [14, 2, 17, 750, 4, 1, 34],
#  [955, 1, 20, 259, 78, 20, 4],
#  [1, 17, 10, 2, 117, 145, 9, 751, 43, 191],
#  [1, 149, 149, 39, 19, 39, 190, 20, 81],
#  [3, 13, 439, 439, 504, 145],
#  [5, 284, 314, 2, 116],
#  [2, 956],
#  [32, 50],
#  [150, 11, 523, 957, 726, 1482],
#  [9, 132, 153, 886, 4],
#  [15, 19, 2, 6, 3, 4, 125, 158, 119, 4, 81, 6],
#  [106, 193, 68, 8, 245, 80],
#  [101, 1483],
#  [602, 4, 75, 958, 21, 113, 202, 513, 258, 1484],
#  [13, 1485, 2, 92],
#  [2, 31, 10],
#  [51, 141, 1, 20, 10, 524, 421, 19, 248, 248, 8, 236, 686],
#  [2, 31, 20, 10, 426, 9, 20, 72, 415, 338, 22],
#  [752, 141, 1486, 1487, 1488, 116, 959, 1],
#  [57, 511, 49, 137, 208],
#  [14, 2, 5, 41, 26, 6, 6, 59, 185, 4, 5, 25, 366, 63, 7, 335],
#  [210, 26, 1, 1, 34],
#  [22, 78, 214, 143, 628, 52],
#  [3, 13, 512, 1489, 18, 3],
#  [14, 2, 1490, 24, 7, 625, 71, 16, 5, 70],
#  [26, 6, 64, 7],
#  [104, 1491, 1492],
#  [3, 6, 753],
#  [1, 50, 14, 2, 79],
#  [8, 5, 1493],
#  [126, 7, 34, 525, 960],
#  [9, 5, 12, 2, 5, 422, 395, 961],
#  [45, 1494, 5, 754, 6],
#  [33, 16, 65],
#  [1495, 8, 3, 38, 120, 120, 629, 8, 384, 755, 3, 1],
#  [349, 37, 49, 6, 24, 7, 8, 18, 136, 93, 8],
#  [20],
#  [2, 5, 30, 17, 12],
#  [22,
#   1496,
#   1,
#   24,
#   7,
#   330,
#   68,
#   54,
#   77,
#   77,
#   68,
#   54,
#   144,
#   350,
#   13,
#   1,
#   6,
#   33,
#   66,
#   49,
#   594],
#  [22, 57],
#  [5, 1],
#  [291, 7, 5, 3],
#  [3, 13, 9],
#  [13, 30, 16, 5],
#  [167, 6, 288],
#  [1, 11, 4],
#  [3, 13],
#  [16, 1497, 2, 12],
#  [29, 1, 313],
#  [5, 4, 36, 630, 320, 57],
#  [270, 1, 18],
#  [1, 36, 17, 12, 213, 4, 274, 865],
#  [32, 119, 273, 9],
#  [61, 1, 5, 1498],
#  [83, 35, 591, 53, 52, 962, 387, 300, 160, 5, 4, 303, 119, 387, 300, 1499],
#  [451,
#   1500,
#   963,
#   138,
#   1501,
#   756,
#   1502,
#   1503,
#   1504,
#   964,
#   90,
#   1505,
#   138,
#   1506,
#   964],
#  [693, 452, 3, 357, 757, 302, 452],
#  [25],
#  [3, 2, 69, 5, 119],
#  [107, 526, 6, 87],
#  [9, 5, 131, 70, 4],
#  [3, 1507, 13, 9],
#  [965, 243],
#  [217],
#  [1, 4, 18, 5, 12, 1508, 12],
#  [161, 2, 423, 1509],
#  [3, 13, 758, 184, 218, 6],
#  [759, 26, 3, 64],
#  [1, 23, 1510, 3, 966],
#  [9, 243, 334, 13, 8, 8],
#  [9, 145],
#  [3, 13, 1, 11],
#  [],
#  [11, 12, 2],
#  [54],
#  [1, 19, 77, 77, 3, 12, 2],
#  [297],
#  [36, 1511],
#  [2, 164, 17, 10],
#  [36, 76, 967, 968, 1512],
#  [3, 151, 263, 324, 151, 8],
#  [8, 147, 3, 1513, 147, 151, 367],
#  [15, 631, 194, 3, 60],
#  [14, 2, 5, 79, 142],
#  [16, 2, 25],
#  [3, 1514, 112, 377, 453],
#  [1515, 215],
#  [8, 15, 236],
#  [15, 40, 1],
#  [1516, 57, 5, 97, 254, 4],
#  [64, 86, 6, 5, 196, 1517, 252, 942, 158],
#  [53, 2, 11],
#  [32, 969],
#  [13, 334],
#  [274, 339, 632, 219, 5, 591, 522, 269, 277],
#  [9, 1],
#  [211, 187, 94, 117, 187],
#  [45, 1, 115, 111, 46],
#  [120, 1, 16],
#  [58, 1],
#  [908, 355, 137, 128, 21, 338],
#  [33, 17, 970, 870, 31],
#  [1],
#  [153, 4, 3, 190, 1],
#  [2, 28, 79, 97, 4, 28, 97, 143, 368, 278, 44, 85],
#  [28,
#   7,
#   38,
#   40,
#   56,
#   15,
#   1518,
#   187,
#   1519,
#   63,
#   7,
#   527,
#   126,
#   454,
#   189,
#   86,
#   1520,
#   570,
#   1521,
#   56,
#   683,
#   1522,
#   229,
#   142,
#   15,
#   528,
#   36,
#   342,
#   971,
#   321,
#   1523,
#   18,
#   89,
#   1524],
#  [5, 1525, 176, 248],
#  [22, 42, 78],
#  [140, 8, 103],
#  [579, 972, 4],
#  [62, 1, 306, 92, 26, 1, 87, 973, 1526, 4, 874, 62, 1, 1527, 1528],
#  [52, 4, 974],
#  [5, 1],
#  [114, 1, 35, 107, 522, 4],
#  [2, 975, 93],
#  [1, 31, 12],
#  [9, 105, 1529, 382, 37, 67, 2],
#  [2, 38, 279, 2, 44, 85, 4, 29, 529],
#  [13, 15, 75, 49, 6, 633, 11, 1],
#  [22, 42, 43, 45, 218, 78, 51, 84, 108, 22],
#  [17, 12, 30, 17, 10],
#  [1530],
#  ...]

# %%
X = pad_sequences(X)
X
# Out:
# array([[   0,    0,    0, ...,    0,    3,   13],
#        [   0,    0,    0, ...,    9,   12,    4],
#        [   0,    0,    0, ...,   16,   56,   21],
#        ...,
#        [   0,    0,    0, ...,    3,   12,    2],
#        [   0,    0,    0, ...,  173,   52, 2634],
#        [   0,    0,    0, ...,    0,    0,    1]])

# %%
X.shape
# Out:
# (4569, 34)

# %%
# Encode target data into numerical values
polarity_encode = {'negative' : 0, 'positive' : 1}
y = coments['sentimenc2np'].map(polarity_encode).values

# Split the data (with composition data train 80%, data test 20%)
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
# print(X_train.shape, y_train.shape)
# print(X_test.shape, y_test.shape)

# %% [markdown]
# ## Model LSTM

# %%
# Create model function with default hyperparameter values

def create_model(embed_dim = 16, hidden_unit = 16, dropout_rate = 0.2, optimizers = Adam, learning_rate = 0.001):
    model = Sequential()
    model.add(Embedding(input_dim = max_features, output_dim = embed_dim, input_length = X.shape[1]))
    model.add(LSTM(units = hidden_unit, activation = 'tanh'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(units = 3, activation = 'softmax'))
    model.compile(loss = 'sparse_categorical_crossentropy', optimizer = optimizers(lr = learning_rate), metrics = ['accuracy'])
    print(model.summary())
    return model

# %%
# Results from hyperparameter tuning
results = pd.read_csv('data/gridsearchcv_results.csv')
results.sort_values(by='means', ascending = False).reset_index(drop=True)
# Out:
#         means      stds                                             params
# 0    0.916513  0.002494  {'batch_size': 128, 'dropout_rate': 0.2, 'embe...
# 1    0.916210  0.012881  {'batch_size': 128, 'dropout_rate': 0.2, 'embe...
# 2    0.915358  0.012066  {'batch_size': 128, 'dropout_rate': 0.2, 'embe...
# 3    0.915012  0.003830  {'batch_size': 128, 'dropout_rate': 0.2, 'embe...
# 4    0.912172  0.008714  {'batch_size': 128, 'dropout_rate': 0.2, 'embe...
# ..        ...       ...                                                ...
# 283  0.651693  0.007537  {'batch_size': 256, 'dropout_rate': 0.2, 'embe...
# 284  0.651693  0.007537  {'batch_size': 256, 'dropout_rate': 0.2, 'embe...
# 285  0.651693  0.007537  {'batch_size': 256, 'dropout_rate': 0.2, 'embe...
# 286  0.651693  0.007537  {'batch_size': 256, 'dropout_rate': 0.2, 'embe...
# 287  0.651693  0.007537  {'batch_size': 256, 'dropout_rate': 0.2, 'embe...
#
# [288 rows x 3 columns]

# %%
# Create the model with the best hyperparameter which has been determined
model = KerasClassifier(build_fn = create_model,
                        # Model Parameters
                        dropout_rate = 0.2,
                        embed_dim = 32,
                        hidden_unit = 16,
                        optimizers = RMSprop,
                        learning_rate = 0.001,
                   
                        # Fit Parameters
                        epochs=10, 
                        batch_size=128,
                        # Initiate validation data, which is 10% data from data train. It's used for evaluation model
                        validation_split = 0.1)

# %%
scoring1 = ['accuracy', 'precision', 'recall', 'f1']

scoring = {'accuracy': make_scorer(accuracy_score),
            'precision': make_scorer(precision_score, average='macro'),
            'recall': make_scorer(recall_score, average='macro'),
            'f1': make_scorer(f1_score, average='macro')
            }

# %%
cv_score = cross_validate(model, X, y, cv=5, scoring=scoring)
cv_score
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 34, 32)            160000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 16)                3136
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# C:\Users\Fury\Anaconda3\envs\myenviroment\lib\site-packages\tensorflow_core\python\framework\indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 3289 samples, validate on 366 samples
# Epoch 1/10
# 3289/3289 [==============================] - 1s 264us/step - loss: 0.8942 - accuracy: 0.5005 - val_loss: 0.7368 - val_accuracy: 0.5765
# Epoch 2/10
# 3289/3289 [==============================] - 0s 138us/step - loss: 0.7290 - accuracy: 0.5363 - val_loss: 0.6972 - val_accuracy: 0.5847
# Epoch 3/10
# 3289/3289 [==============================] - 0s 138us/step - loss: 0.6888 - accuracy: 0.5838 - val_loss: 0.6576 - val_accuracy: 0.6885
# Epoch 4/10
# 3289/3289 [==============================] - 0s 132us/step - loss: 0.6282 - accuracy: 0.7042 - val_loss: 0.6015 - val_accuracy: 0.7568
# Epoch 5/10
# 3289/3289 [==============================] - 0s 134us/step - loss: 0.5516 - accuracy: 0.7717 - val_loss: 0.5349 - val_accuracy: 0.7705
# Epoch 6/10
# 3289/3289 [==============================] - 0s 129us/step - loss: 0.4741 - accuracy: 0.8212 - val_loss: 0.4924 - val_accuracy: 0.7814
# Epoch 7/10
# 3289/3289 [==============================] - 0s 132us/step - loss: 0.4174 - accuracy: 0.8516 - val_loss: 0.4577 - val_accuracy: 0.8060
# Epoch 8/10
# 3289/3289 [==============================] - 0s 132us/step - loss: 0.3726 - accuracy: 0.8638 - val_loss: 0.4409 - val_accuracy: 0.8224
# Epoch 9/10
# 3289/3289 [==============================] - 0s 132us/step - loss: 0.3446 - accuracy: 0.8702 - val_loss: 0.4173 - val_accuracy: 0.8388
# Epoch 10/10
# 3289/3289 [==============================] - 0s 145us/step - loss: 0.3124 - accuracy: 0.8866 - val_loss: 0.4099 - val_accuracy: 0.8224
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 34, 32)            160000
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 16)                3136
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# C:\Users\Fury\Anaconda3\envs\myenviroment\lib\site-packages\tensorflow_core\python\framework\indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 3289 samples, validate on 366 samples
# Epoch 1/10
# 3289/3289 [==============================] - 1s 254us/step - loss: 0.8904 - accuracy: 0.5445 - val_loss: 0.7154 - val_accuracy: 0.5765
# Epoch 2/10
# 3289/3289 [==============================] - 0s 137us/step - loss: 0.7166 - accuracy: 0.5652 - val_loss: 0.6637 - val_accuracy: 0.6557
# Epoch 3/10
# 3289/3289 [==============================] - 0s 134us/step - loss: 0.6457 - accuracy: 0.6680 - val_loss: 0.5960 - val_accuracy: 0.7158
# Epoch 4/10
# 3289/3289 [==============================] - 0s 131us/step - loss: 0.5559 - accuracy: 0.7470 - val_loss: 0.5369 - val_accuracy: 0.7732
# Epoch 5/10
# 3289/3289 [==============================] - 0s 133us/step - loss: 0.4911 - accuracy: 0.7948 - val_loss: 0.4839 - val_accuracy: 0.8115
# Epoch 6/10
# 3289/3289 [==============================] - 0s 133us/step - loss: 0.4227 - accuracy: 0.8322 - val_loss: 0.4453 - val_accuracy: 0.8224
# Epoch 7/10
# 3289/3289 [==============================] - 0s 135us/step - loss: 0.3823 - accuracy: 0.8525 - val_loss: 0.4155 - val_accuracy: 0.8333
# Epoch 8/10
# 3289/3289 [==============================] - 0s 136us/step - loss: 0.3381 - accuracy: 0.8708 - val_loss: 0.4198 - val_accuracy: 0.8115
# Epoch 9/10
# 3289/3289 [==============================] - 0s 134us/step - loss: 0.3171 - accuracy: 0.8784 - val_loss: 0.3991 - val_accuracy: 0.8333
# Epoch 10/10
# 3289/3289 [==============================] - 0s 137us/step - loss: 0.2960 - accuracy: 0.8918 - val_loss: 0.4112 - val_accuracy: 0.8333
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 34, 32)            160000
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 16)                3136
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# C:\Users\Fury\Anaconda3\envs\myenviroment\lib\site-packages\tensorflow_core\python\framework\indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 3289 samples, validate on 366 samples
# Epoch 1/10
# 3289/3289 [==============================] - 1s 241us/step - loss: 0.9331 - accuracy: 0.5236 - val_loss: 0.7406 - val_accuracy: 0.5847
# Epoch 2/10
# 3289/3289 [==============================] - 0s 139us/step - loss: 0.7078 - accuracy: 0.6114 - val_loss: 0.6639 - val_accuracy: 0.6858
# Epoch 3/10
# 3289/3289 [==============================] - 0s 141us/step - loss: 0.6266 - accuracy: 0.6859 - val_loss: 0.5875 - val_accuracy: 0.7077
# Epoch 4/10
# 3289/3289 [==============================] - 0s 138us/step - loss: 0.5484 - accuracy: 0.7513 - val_loss: 0.5436 - val_accuracy: 0.7268
# Epoch 5/10
# 3289/3289 [==============================] - 0s 139us/step - loss: 0.4916 - accuracy: 0.7966 - val_loss: 0.5181 - val_accuracy: 0.7377
# Epoch 6/10
# 3289/3289 [==============================] - 0s 138us/step - loss: 0.4275 - accuracy: 0.8346 - val_loss: 0.4923 - val_accuracy: 0.7787
# Epoch 7/10
# 3289/3289 [==============================] - 0s 139us/step - loss: 0.3991 - accuracy: 0.8480 - val_loss: 0.4403 - val_accuracy: 0.8197
# Epoch 8/10
# 3289/3289 [==============================] - 0s 139us/step - loss: 0.3661 - accuracy: 0.8565 - val_loss: 0.4821 - val_accuracy: 0.7623
# Epoch 9/10
# 3289/3289 [==============================] - 0s 139us/step - loss: 0.3448 - accuracy: 0.8671 - val_loss: 0.4193 - val_accuracy: 0.8197
# Epoch 10/10
# 3289/3289 [==============================] - 0s 137us/step - loss: 0.3165 - accuracy: 0.8826 - val_loss: 0.4432 - val_accuracy: 0.8142
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 34, 32)            160000
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 16)                3136
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# C:\Users\Fury\Anaconda3\envs\myenviroment\lib\site-packages\tensorflow_core\python\framework\indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 3289 samples, validate on 366 samples
# Epoch 1/10
# 3289/3289 [==============================] - 1s 237us/step - loss: 0.9199 - accuracy: 0.5220 - val_loss: 0.7395 - val_accuracy: 0.5765
# Epoch 2/10
# 3289/3289 [==============================] - 0s 132us/step - loss: 0.7499 - accuracy: 0.5473 - val_loss: 0.6879 - val_accuracy: 0.6339
# Epoch 3/10
# 3289/3289 [==============================] - 0s 138us/step - loss: 0.6814 - accuracy: 0.6245 - val_loss: 0.6345 - val_accuracy: 0.6831
# Epoch 4/10
# 3289/3289 [==============================] - 0s 133us/step - loss: 0.5946 - accuracy: 0.7267 - val_loss: 0.5671 - val_accuracy: 0.7732
# Epoch 5/10
# 3289/3289 [==============================] - 0s 147us/step - loss: 0.5094 - accuracy: 0.7820 - val_loss: 0.5327 - val_accuracy: 0.7650
# Epoch 6/10
# 3289/3289 [==============================] - 0s 147us/step - loss: 0.4426 - accuracy: 0.8224 - val_loss: 0.4770 - val_accuracy: 0.8005
# Epoch 7/10
# 3289/3289 [==============================] - 0s 137us/step - loss: 0.3936 - accuracy: 0.8437 - val_loss: 0.4617 - val_accuracy: 0.8087
# Epoch 8/10
# 3289/3289 [==============================] - 0s 136us/step - loss: 0.3597 - accuracy: 0.8653 - val_loss: 0.4391 - val_accuracy: 0.8033
# Epoch 9/10
# 3289/3289 [==============================] - 0s 135us/step - loss: 0.3382 - accuracy: 0.8650 - val_loss: 0.4307 - val_accuracy: 0.8115
# Epoch 10/10
# 3289/3289 [==============================] - 0s 131us/step - loss: 0.3137 - accuracy: 0.8781 - val_loss: 0.4309 - val_accuracy: 0.8033
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 34, 32)            160000
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 16)                3136
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# C:\Users\Fury\Anaconda3\envs\myenviroment\lib\site-packages\tensorflow_core\python\framework\indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 3290 samples, validate on 366 samples
# Epoch 1/10
# 3290/3290 [==============================] - 1s 245us/step - loss: 0.9280 - accuracy: 0.5544 - val_loss: 0.7583 - val_accuracy: 0.5519
# Epoch 2/10
# 3290/3290 [==============================] - 0s 143us/step - loss: 0.7255 - accuracy: 0.5985 - val_loss: 0.6660 - val_accuracy: 0.6913
# Epoch 3/10
# 3290/3290 [==============================] - 0s 141us/step - loss: 0.6475 - accuracy: 0.6748 - val_loss: 0.5958 - val_accuracy: 0.7295
# Epoch 4/10
# 3290/3290 [==============================] - 0s 140us/step - loss: 0.5701 - accuracy: 0.7465 - val_loss: 0.5357 - val_accuracy: 0.8251
# Epoch 5/10
# 3290/3290 [==============================] - 0s 140us/step - loss: 0.4958 - accuracy: 0.7933 - val_loss: 0.5274 - val_accuracy: 0.7678
# Epoch 6/10
# 3290/3290 [==============================] - 0s 138us/step - loss: 0.4485 - accuracy: 0.8225 - val_loss: 0.4413 - val_accuracy: 0.8115
# Epoch 7/10
# 3290/3290 [==============================] - 0s 138us/step - loss: 0.3969 - accuracy: 0.8523 - val_loss: 0.4087 - val_accuracy: 0.8333
# Epoch 8/10
# 3290/3290 [==============================] - 0s 136us/step - loss: 0.3638 - accuracy: 0.8657 - val_loss: 0.4138 - val_accuracy: 0.8415
# Epoch 9/10
# 3290/3290 [==============================] - 0s 137us/step - loss: 0.3369 - accuracy: 0.8711 - val_loss: 0.4264 - val_accuracy: 0.8415
# Epoch 10/10
# 3290/3290 [==============================] - 0s 141us/step - loss: 0.3115 - accuracy: 0.8824 - val_loss: 0.3989 - val_accuracy: 0.8197
# {'fit_time': array([6.00543356, 5.83285832, 6.02021646, 5.82559466, 6.06740451]),
#  'score_time': array([0.16501164, 0.15303206, 0.15309644, 0.15199876, 0.15905881]),
#  'test_accuracy': array([0.80415755, 0.82056893, 0.81728665, 0.84682713, 0.81708653]),
#  'test_precision': array([0.80121809, 0.82516017, 0.83202289, 0.84704434, 0.83255205]),
#  'test_recall': array([0.8050037 , 0.81621861, 0.80436236, 0.84612582, 0.80308885]),
#  'test_f1': array([0.80228285, 0.81793183, 0.80912496, 0.84643817, 0.80824948])}

# %%
cv_pred = cross_val_predict(model, X, y, cv=5)
print("Accuracy Score",accuracy_score(y, cv_pred))
print("Precision Score",precision_score(y, cv_pred, average='macro'))
print("Recall Score",recall_score(y, cv_pred, average='macro'))
print("F1 Score",f1_score(y, cv_pred, average='macro'))
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, 34, 32)            160000
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 16)                3136
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# C:\Users\Fury\Anaconda3\envs\myenviroment\lib\site-packages\tensorflow_core\python\framework\indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 3289 samples, validate on 366 samples
# Epoch 1/10
# 3289/3289 [==============================] - 1s 241us/step - loss: 0.8952 - accuracy: 0.5303 - val_loss: 0.7295 - val_accuracy: 0.5765
# Epoch 2/10
# 3289/3289 [==============================] - 0s 134us/step - loss: 0.7320 - accuracy: 0.5497 - val_loss: 0.6800 - val_accuracy: 0.5984
# Epoch 3/10
# 3289/3289 [==============================] - 0s 137us/step - loss: 0.6708 - accuracy: 0.6279 - val_loss: 0.6371 - val_accuracy: 0.7077
# Epoch 4/10
# 3289/3289 [==============================] - 0s 141us/step - loss: 0.6102 - accuracy: 0.7066 - val_loss: 0.5906 - val_accuracy: 0.7404
# Epoch 5/10
# 3289/3289 [==============================] - 0s 138us/step - loss: 0.5298 - accuracy: 0.7714 - val_loss: 0.5242 - val_accuracy: 0.7568
# Epoch 6/10
# 3289/3289 [==============================] - 0s 138us/step - loss: 0.4624 - accuracy: 0.8103 - val_loss: 0.4871 - val_accuracy: 0.7896
# Epoch 7/10
# 3289/3289 [==============================] - 0s 143us/step - loss: 0.4104 - accuracy: 0.8434 - val_loss: 0.4745 - val_accuracy: 0.7923
# Epoch 8/10
# 3289/3289 [==============================] - 0s 139us/step - loss: 0.3733 - accuracy: 0.8614 - val_loss: 0.4361 - val_accuracy: 0.8169
# Epoch 9/10
# 3289/3289 [==============================] - 0s 140us/step - loss: 0.3432 - accuracy: 0.8732 - val_loss: 0.4270 - val_accuracy: 0.8169
# Epoch 10/10
# 3289/3289 [==============================] - 0s 140us/step - loss: 0.3122 - accuracy: 0.8814 - val_loss: 0.4213 - val_accuracy: 0.8388
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_7 (Embedding)      (None, 34, 32)            160000
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 16)                3136
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# C:\Users\Fury\Anaconda3\envs\myenviroment\lib\site-packages\tensorflow_core\python\framework\indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 3289 samples, validate on 366 samples
# Epoch 1/10
# 3289/3289 [==============================] - 1s 278us/step - loss: 0.8980 - accuracy: 0.5056 - val_loss: 0.7025 - val_accuracy: 0.5765
# Epoch 2/10
# 3289/3289 [==============================] - 1s 161us/step - loss: 0.6882 - accuracy: 0.5886 - val_loss: 0.6678 - val_accuracy: 0.6585
# Epoch 3/10
# 3289/3289 [==============================] - 1s 153us/step - loss: 0.6358 - accuracy: 0.6507 - val_loss: 0.5883 - val_accuracy: 0.7049
# Epoch 4/10
# 3289/3289 [==============================] - 1s 155us/step - loss: 0.5747 - accuracy: 0.7288 - val_loss: 0.5505 - val_accuracy: 0.7760
# Epoch 5/10
# 3289/3289 [==============================] - 0s 143us/step - loss: 0.5223 - accuracy: 0.7741 - val_loss: 0.5184 - val_accuracy: 0.7432
# Epoch 6/10
# 3289/3289 [==============================] - 1s 154us/step - loss: 0.4730 - accuracy: 0.8051 - val_loss: 0.4731 - val_accuracy: 0.8115
# Epoch 7/10
# 3289/3289 [==============================] - 1s 352us/step - loss: 0.4292 - accuracy: 0.8340 - val_loss: 0.4747 - val_accuracy: 0.7869
# Epoch 8/10
# 3289/3289 [==============================] - 1s 392us/step - loss: 0.3906 - accuracy: 0.8507 - val_loss: 0.4301 - val_accuracy: 0.8169
# Epoch 9/10
# 3289/3289 [==============================] - 1s 388us/step - loss: 0.3635 - accuracy: 0.8592 - val_loss: 0.4276 - val_accuracy: 0.8279
# Epoch 10/10
# 3289/3289 [==============================] - 1s 384us/step - loss: 0.3430 - accuracy: 0.8723 - val_loss: 0.4208 - val_accuracy: 0.8279
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_8 (Embedding)      (None, 34, 32)            160000
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 16)                3136
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# C:\Users\Fury\Anaconda3\envs\myenviroment\lib\site-packages\tensorflow_core\python\framework\indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 3289 samples, validate on 366 samples
# Epoch 1/10
# 3289/3289 [==============================] - 1s 236us/step - loss: 0.9311 - accuracy: 0.5625 - val_loss: 0.7373 - val_accuracy: 0.5902
# Epoch 2/10
# 3289/3289 [==============================] - 0s 132us/step - loss: 0.7147 - accuracy: 0.6102 - val_loss: 0.6651 - val_accuracy: 0.6366
# Epoch 3/10
# 3289/3289 [==============================] - 0s 134us/step - loss: 0.6442 - accuracy: 0.6741 - val_loss: 0.6081 - val_accuracy: 0.6967
# Epoch 4/10
# 3289/3289 [==============================] - 0s 131us/step - loss: 0.5698 - accuracy: 0.7479 - val_loss: 0.5537 - val_accuracy: 0.7514
# Epoch 5/10
# 3289/3289 [==============================] - 0s 133us/step - loss: 0.5081 - accuracy: 0.7936 - val_loss: 0.5208 - val_accuracy: 0.7350
# Epoch 6/10
# 3289/3289 [==============================] - 0s 131us/step - loss: 0.4514 - accuracy: 0.8173 - val_loss: 0.4765 - val_accuracy: 0.8087
# Epoch 7/10
# 3289/3289 [==============================] - 0s 137us/step - loss: 0.4090 - accuracy: 0.8389 - val_loss: 0.5161 - val_accuracy: 0.7322
# Epoch 8/10
# 3289/3289 [==============================] - 0s 135us/step - loss: 0.3739 - accuracy: 0.8595 - val_loss: 0.4405 - val_accuracy: 0.8060
# Epoch 9/10
# 3289/3289 [==============================] - 0s 134us/step - loss: 0.3415 - accuracy: 0.8729 - val_loss: 0.4304 - val_accuracy: 0.8197
# Epoch 10/10
# 3289/3289 [==============================] - 0s 134us/step - loss: 0.3239 - accuracy: 0.8753 - val_loss: 0.4274 - val_accuracy: 0.8197
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_9 (Embedding)      (None, 34, 32)            160000
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 16)                3136
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# C:\Users\Fury\Anaconda3\envs\myenviroment\lib\site-packages\tensorflow_core\python\framework\indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 3289 samples, validate on 366 samples
# Epoch 1/10
# 3289/3289 [==============================] - 1s 263us/step - loss: 0.9354 - accuracy: 0.5479 - val_loss: 0.7444 - val_accuracy: 0.5765
# Epoch 2/10
# 3289/3289 [==============================] - 0s 143us/step - loss: 0.7208 - accuracy: 0.5777 - val_loss: 0.6694 - val_accuracy: 0.6120
# Epoch 3/10
# 3289/3289 [==============================] - 0s 139us/step - loss: 0.6655 - accuracy: 0.6272 - val_loss: 0.6271 - val_accuracy: 0.6639
# Epoch 4/10
# 3289/3289 [==============================] - 0s 133us/step - loss: 0.6084 - accuracy: 0.7051 - val_loss: 0.6117 - val_accuracy: 0.7268
# Epoch 5/10
# 3289/3289 [==============================] - 0s 132us/step - loss: 0.5442 - accuracy: 0.7616 - val_loss: 0.5378 - val_accuracy: 0.7432
# Epoch 6/10
# 3289/3289 [==============================] - 0s 134us/step - loss: 0.4856 - accuracy: 0.8069 - val_loss: 0.4991 - val_accuracy: 0.8087
# Epoch 7/10
# 3289/3289 [==============================] - 0s 133us/step - loss: 0.4408 - accuracy: 0.8349 - val_loss: 0.4629 - val_accuracy: 0.8251
# Epoch 8/10
# 3289/3289 [==============================] - 0s 132us/step - loss: 0.3969 - accuracy: 0.8544 - val_loss: 0.4533 - val_accuracy: 0.8060
# Epoch 9/10
# 3289/3289 [==============================] - 0s 134us/step - loss: 0.3685 - accuracy: 0.8620 - val_loss: 0.4384 - val_accuracy: 0.8169
# Epoch 10/10
# 3289/3289 [==============================] - 0s 131us/step - loss: 0.3449 - accuracy: 0.8677 - val_loss: 0.4208 - val_accuracy: 0.8251
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_10 (Embedding)     (None, 34, 32)            160000
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 16)                3136
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 3)                 51
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# C:\Users\Fury\Anaconda3\envs\myenviroment\lib\site-packages\tensorflow_core\python\framework\indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 3290 samples, validate on 366 samples
# Epoch 1/10
# 3290/3290 [==============================] - 1s 236us/step - loss: 0.8547 - accuracy: 0.5422 - val_loss: 0.7196 - val_accuracy: 0.5273
# Epoch 2/10
# 3290/3290 [==============================] - 0s 133us/step - loss: 0.7021 - accuracy: 0.5556 - val_loss: 0.6809 - val_accuracy: 0.5574
# Epoch 3/10
# 3290/3290 [==============================] - 0s 133us/step - loss: 0.6689 - accuracy: 0.6112 - val_loss: 0.6487 - val_accuracy: 0.5984
# Epoch 4/10
# 3290/3290 [==============================] - 0s 134us/step - loss: 0.6269 - accuracy: 0.6830 - val_loss: 0.6026 - val_accuracy: 0.7760
# Epoch 5/10
# 3290/3290 [==============================] - 0s 132us/step - loss: 0.5777 - accuracy: 0.7398 - val_loss: 0.5614 - val_accuracy: 0.6967
# Epoch 6/10
# 3290/3290 [==============================] - 0s 132us/step - loss: 0.5252 - accuracy: 0.7818 - val_loss: 0.5075 - val_accuracy: 0.8251
# Epoch 7/10
# 3290/3290 [==============================] - 0s 131us/step - loss: 0.4741 - accuracy: 0.8116 - val_loss: 0.4711 - val_accuracy: 0.8087
# Epoch 8/10
# 3290/3290 [==============================] - 0s 132us/step - loss: 0.4342 - accuracy: 0.8340 - val_loss: 0.4437 - val_accuracy: 0.8443
# Epoch 9/10
# 3290/3290 [==============================] - 0s 133us/step - loss: 0.3971 - accuracy: 0.8571 - val_loss: 0.4172 - val_accuracy: 0.8251
# Epoch 10/10
# 3290/3290 [==============================] - 0s 135us/step - loss: 0.3661 - accuracy: 0.8550 - val_loss: 0.3961 - val_accuracy: 0.8388
# Accuracy Score 0.8260013131976363
# Precision Score 0.8265520282186949
# Recall Score 0.8219023279264244
# F1 Score 0.8234805294774985

# %%
print("Accuracy each fold :", cv_score['test_accuracy'])
print("Precision each fold :", cv_score['test_precision'])
print("Recall each fold :", cv_score['test_recall'])
print("F1 each fold :", cv_score['test_f1'])
# Out:
# Accuracy each fold : [0.80415755 0.82056893 0.81728665 0.84682713 0.81708653]
# Precision each fold : [0.80121809 0.82516017 0.83202289 0.84704434 0.83255205]
# Recall each fold : [0.8050037  0.81621861 0.80436236 0.84612582 0.80308885]
# F1 each fold : [0.80228285 0.81793183 0.80912496 0.84643817 0.80824948]

# %%
cv_pred
# Out:
# array([1, 1, 1, ..., 0, 1, 1], dtype=int64)

# %%
conf_mat = confusion_matrix(y, cv_pred)
conf_mat
# Out:
# array([[1614,  465],
#        [ 330, 2160]], dtype=int64)

# %%
print("Accuracy average :", cv_score['test_accuracy'].mean())
print("Precision average :", cv_score['test_precision'].mean())
print("Recall average :", cv_score['test_recall'].mean())
print("F1 average :", cv_score['test_f1'].mean())
# Out:
# Accuracy average : 0.8211853581023917
# Precision average : 0.8275995079473801
# Recall average : 0.8149598660719682
# F1 average : 0.8168054568552592

# %%
print("Standard Deviation of Accuracy is % s " % (statistics.stdev(cv_score['test_accuracy'])))
print("Standard Deviation of Precision is % s " % (statistics.stdev(cv_score['test_precision'])))
print("Standard Deviation of Recall is % s " % (statistics.stdev(cv_score['test_recall'])))
print("Standard Deviation of F1 is % s " % (statistics.stdev(cv_score['test_f1'])))
# Out:
# Standard Deviation of Accuracy is 0.015651095992779557
# Standard Deviation of Precision is 0.016763989663761306
# Standard Deviation of Recall is 0.018202020809520065
# Standard Deviation of F1 is 0.01748190108436227
